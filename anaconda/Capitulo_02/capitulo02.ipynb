# %% [markdown]
# # Variaveis

# %%
numero = 20

# %%
numero
# Out:
# 20

# %%
numero = 50

# %%
numero
# Out:
# 50

# %%
type(numero)
# Out:
# int

# %%
pi = 3.14

# %%
pi
# Out:
# 3.14

# %%
type(pi)
# Out:
# float

# %%
mensagem = "Curso de python da Impacta"

# %%
mensagem
# Out:
# 'Curso de python da Impacta'

# %%
type(mensagem)
# Out:
# str

# %%
numero + 100
# Out:
# 150

# %%
round(pi)
# Out:
# 3

# %%
len(mensagem)
# Out:
# 26

# %% [markdown]
# # Nomes Variáveis

# %%
qualoNome? = "Teste"
# Out:
#   Cell In[17], line 1
#     qualoNome? = "Teste"
#              ^
# SyntaxError: invalid syntax

# %%
25centavos  = "valor"
# Out:
#   Cell In[18], line 1
#     25centavos  = "valor"
#      ^
# SyntaxError: invalid decimal literal

# %%
centavos25  =  "valor"

# %%
centavos25
# Out:
# 'valor'

# %%
class = "Turma segunda a quinta"
# Out:
#   Cell In[21], line 1
#     class = "Turma segunda a quinta"
#           ^
# SyntaxError: invalid syntax

# %%
Class = "Turma segunda a quinta"

# %%
Class
# Out:
# 'Turma segunda a quinta'

# %% [markdown]
# # Declaração Import

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
math.pow(5, 2)
# Out:
# 25.0

# %%
5 ** 2
# Out:
# 25

# %%
numero
# Out:
# 50

# %%
10 + numero - round(math.pi)  * 5
# Out:
# 45

# %% [markdown]
# # print

# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
"Olá Mundo"
# Out:
# 'Olá Mundo'

# %%
numero
numero * 2
numero * 3
# Out:
# 150

# %%
print(numero)
print(numero * 2)
print(numero * 3)
# Out:
# 50
# 100
# 150

# %% [markdown]
# # Argumentos

# %%
round(10.5, 0)
# Out:
# 10.0

# %%
print("Claudir", "Ana", "Everton", "Matheus", "Nathalia", sep='\n')
# Out:
# Claudir
# Ana
# Everton
# Matheus
# Nathalia

# %%
print("Olá",end='-')
print("Mundo")
# Out:
# Olá-Mundo

# %% [markdown]
# # Comentários

# %%
# calculo da vida útil do veiculo
idade =  100 / 5

# %%
dia = "Segunda-feira" # demonstra o dia atual

# %%
# Este é um comentário
# Este também
# E este também
# mensagem = "Acima exemplos de comentários"
mensagem = "Acima exemplos alterado"
