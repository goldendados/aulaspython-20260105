# %% [markdown]
# # Lista é uma sequência

# %%
numeros = [10,20,30]

# %%
type(numeros)
# Out:
# list

# %%
numeros[1]
# Out:
# 20

# %%
numeros[1:3]
# Out:
# [20, 30]

# %%
queijos = ['Cheddar', 'Edam', 'Gouda']

# %%
type(queijos)
# Out:
# list

# %%
queijos[2]
# Out:
# 'Gouda'

# %%
type(queijos[2])
# Out:
# str

# %%
lista = ['Olá', 2.50,  180, [10, 20]]

# %%
type(lista)
# Out:
# list

# %%
len(lista)
# Out:
# 4

# %%
lista[2]
# Out:
# 180

# %%
lista[3][1]
# Out:
# 20

# %%
nome = "Rose"

# %%
nome[2] =  "z"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 nome[2] =  "z"
#
# TypeError: 'str' object does not support item assignment

# %%
nome = "Roze"
nome
# Out:
# 'Roze'

# %%
nomeLista = ["R","o","s","e"]

# %%
nomeLista[2]="z"

# %%
nomeLista
# Out:
# ['R', 'o', 'z', 'e']

# %%
"a" in "Nathália"
# Out:
# True

# %%
queijos
# Out:
# ['Cheddar', 'Edam', 'Gouda']

# %%
'Cheddar' in queijos
# Out:
# True

# %%
'cheddar' in queijos
# Out:
# False

# %%
lista
# Out:
# ['Olá', 2.5, 180, [10, 20]]

# %%
180 in lista
# Out:
# True

# %%
10  in lista
# Out:
# False

# %%
10 in lista[3]
# Out:
# True

# %% [markdown]
# # Operações e métodos de lista

# %%
l1 = [10, 20, 30]
l2 = [30, 40, 50]
l1 + l2
# Out:
# [10, 20, 30, 30, 40, 50]

# %%
['Olá','Tchau']  * 4
# Out:
# ['Olá', 'Tchau', 'Olá', 'Tchau', 'Olá', 'Tchau', 'Olá', 'Tchau']

# %%
sum(l1)
# Out:
# 60

# %%
min(l2)
# Out:
# 30

# %%
max(l1)
# Out:
# 30

# %%
letras = ['a','b','c','d']

# %%
letras.append('e')

# %%
letras
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
letras.extend(['f','g'])

# %%
letras
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letras[1]
# Out:
# 'b'

# %%
letras.pop(1)
# Out:
# 'b'

# %%
letras
# Out:
# ['a', 'c', 'd', 'e', 'f', 'g']

# %%
letras.remove('d')

# %%
letras
# Out:
# ['a', 'c', 'e', 'f', 'g']

# %%
letras.insert(0,'f')

# %%
letras
# Out:
# ['f', 'a', 'c', 'e', 'f', 'g']

# %%
letras.remove('f')

# %%
letras
# Out:
# ['a', 'c', 'e', 'f', 'g']

# %%
nome = "Everton"

# %%
nomeLista = list(nome)

# %%
nomeLista
# Out:
# ['E', 'v', 'e', 'r', 't', 'o', 'n']

# %%
frase = "Estamos no curso de python"

# %%
fraseLista = frase.split()

# %%
fraseLista
# Out:
# ['Estamos', 'no', 'curso', 'de', 'python']

# %%
frase2 = "Estamos|no|curso|de|python"

# %%
fraseLista2 = frase2.split("|")
fraseLista2
# Out:
# ['Estamos', 'no', 'curso', 'de', 'python']

# %%
texto = " ".join(fraseLista2)
texto
# Out:
# 'Estamos no curso de python'

# %%
texto2 = "|".join(fraseLista2)
texto2
# Out:
# 'Estamos|no|curso|de|python'

# %%
alunos = ['Ana','Everton','Matheus','Claudir','Nathália']

# %%
for nome in alunos:
    print(nome)
# Out:
# Ana
# Everton
# Matheus
# Claudir
# Nathália

# %%
sorted(alunos)
# Out:
# ['Ana', 'Claudir', 'Everton', 'Matheus', 'Nathália']

# %%
alunos
# Out:
# ['Ana', 'Everton', 'Matheus', 'Claudir', 'Nathália']

# %%
alunos = sorted(alunos)

# %%
alunos
# Out:
# ['Ana', 'Claudir', 'Everton', 'Matheus', 'Nathália']

# %%
a =[1,2,3]
b = a
b
# Out:
# [1, 2, 3]

# %%
b is a
# Out:
# True

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 4, 4, 4]

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
b.append(5)

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b
# Out:
# [1, 2, 3, 4, 5]

# %%
from os.path import basename, exists
def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print("local:", local)
        print("_", _)
        print("Downloaded " + str(local))
    return filename

# %%
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt');

# %%
palavrasLista = []

for linha in open('words.txt'):
    palavra = linha.strip()
    palavrasLista.append(palavra)

len(palavrasLista)
# Out:
# 113783

# %%
palavrasLista[:10]
# Out:
# ['aa',
#  'aah',
#  'aahed',
#  'aahing',
#  'aahs',
#  'aal',
#  'aalii',
#  'aaliis',
#  'aals',
#  'aardvark']

# %%
texto = open('words.txt').read()
len(texto)
# Out:
# 1016511

# %%
palavrasLista2 = texto.split()

# %%
len(palavrasLista2)
# Out:
# 113783

# %%
lista = open('words.txt').read().split()
len(lista)
# Out:
# 113783

# %%
lista[:5]
# Out:
# ['aa', 'aah', 'aahed', 'aahing', 'aahs']

# %%
'ola' in lista
# Out:
# False

# %%
'aahing' in lista
# Out:
# True
