# %% [markdown]
# # Operadores Aritméticos

# %% [markdown]
# Um operador aritmético é um simbolo que representa um cálculo aritmético. Por exemplo, o sinal de "+", realiza uma adição.

# %%
30 + 12
# Out:
# 42

# %%
50-5
# Out:
# 45

# %%
12 * 2
# Out:
# 24

# %%
25 / 2
# Out:
# 12.5

# %%
25 ^ 2
# Out:
# 27

# %%
25 ** 2
# Out:
# 625

# %%
3 ** 3
# Out:
# 27

# %%
51 / 2
# Out:
# 25.5

# %%
51 // 2
# Out:
# 25

# %% [markdown]
# # Expressões

# %%
6 + 6 ** 2
# Out:
# 42

# %%
(6 + 6) ** 2
# Out:
# 144

# %% [markdown]
# # Funções Aritméticas

# %%
round(25.5,0)
# Out:
# 26.0

# %%
round(25.4,0)
# Out:
# 25.0

# %%
round(25.5589,2)
# Out:
# 25.56

# %%
round(51/2,0)
# Out:
# 26.0

# %%
abs(-150)
# Out:
# 150

# %%
abs -150
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 abs -150
#
# TypeError: unsupported operand type(s) for -: 'builtin_function_or_method' and 'int'

# %%
abs
# Out:
# <function abs(x, /)>

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %% [markdown]
# # Texto

# %%
'Olá'
# Out:
# 'Olá'

# %%
"Olá"
# Out:
# 'Olá'

# %%
"Olá Mundo"
# Out:
# 'Olá Mundo'

# %%
'Estamos no curso de python'
# Out:
# 'Estamos no curso de python'

# %%
'Curso' + ' '  +  'Impacta'
# Out:
# 'Curso Impacta'

# %%
'?' * 10
# Out:
# '??????????'

# %%
len('Hoje é a primeira segunda-feira de 2026')
# Out:
# 39

# %%
len('Everton')
# Out:
# 7

# %% [markdown]
# # Tipos de dados

# %%
type(25)
# Out:
# int

# %%
type(25.0)
# Out:
# float

# %%
type("25")
# Out:
# str

# %%
"25" + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 "25" + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
"25" + "2"
# Out:
# '252'

# %%
int("25") + 2
# Out:
# 27

# %%
2 +  "25"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 2 +  "25"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(2) +  "25"
# Out:
# '225'
