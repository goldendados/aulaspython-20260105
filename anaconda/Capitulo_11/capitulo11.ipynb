# %% [markdown]
# # Tuplas são como Listas

# %%
tupla = ()

# %%
type(tupla)
# Out:
# tuple

# %%
tupla = "I","m", "p","a","c","t","a"

# %%
tupla
# Out:
# ('I', 'm', 'p', 'a', 'c', 't', 'a')

# %%
a = 10

# %%
b = 20

# %%
valores = a, b

# %%
valores
# Out:
# (10, 20)

# %%
b
# Out:
# 20

# %%
tupla  = tuple("Impacta")

# %%
tupla[1]
# Out:
# 'm'

# %%
tupla[1:3]
# Out:
# ('m', 'p')

# %%
tupla[1]="n"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tupla[1]="n"
#
# TypeError: 'tuple' object does not support item assignment

# %%
email = "joao@impacta.com.br"

# %%
usuario, dominio = email.split("@")

# %%
usuario, dominio
# Out:
# ('joao', 'impacta.com.br')

# %%
tuplauser = usuario, dominio

# %%
tuplauser
# Out:
# ('joao', 'impacta.com.br')

# %%
dicionario = {"um":  1, "dois": 2, "três": 3}

# %%
for chave in dicionario:
    valor = dicionario[chave]
    print(chave, ": ", valor, sep="")
# Out:
# um: 1
# dois: 2
# três: 3

# %%
for chave, valor in  dicionario.items():
    print(chave, ": ", valor, sep="")
# Out:
# um: 1
# dois: 2
# três: 3
